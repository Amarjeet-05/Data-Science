# %%
import pandas as pd 
import requests
from bs4 import BeautifulSoup

# %%
for i in range(1,11):
    a = requests.get(f"https://books.toscrape.com/catalogue/page-{i}.html")
    with open(f"html/Pageno{i}.html", "w") as f:
        f.write(a.text)
        print(f"page {i} Downloaded Sucessfully !")
# Out:
# page 1 Downloaded Sucessfully !
# page 2 Downloaded Sucessfully !
# page 3 Downloaded Sucessfully !
# page 4 Downloaded Sucessfully !
# page 5 Downloaded Sucessfully !
# page 6 Downloaded Sucessfully !
# page 7 Downloaded Sucessfully !
# page 8 Downloaded Sucessfully !
# page 9 Downloaded Sucessfully !
# page 10 Downloaded Sucessfully !

# %%
item = [] 
for i in range(1,11): 
    with open(f"html/Pageno{i}.html") as f: 
        content = f.read()
    soup = BeautifulSoup(content, "html.parser")
    articles = soup.select("article.product_pod")
    for article in articles:
        title = article.find("h3").find("a")['title']
        price = article.select_one("p.price_color").text.split('£')[1]
        rating_ele = article.select_one("p.star-rating")
        rating = rating_ele['class'][1]
        item.append([title, price, rating])

# %%
df = pd.DataFrame(item, columns=['Books Title', 'Price', 'Rating'])

# %%
df
# Out:
#                                            Books Title  Price Rating
# 0                                 A Light in the Attic  51.77  Three
# 1                                   Tipping the Velvet  53.74    One
# 2                                           Soumission  50.10    One
# 3                                        Sharp Objects  47.82   Four
# 4                Sapiens: A Brief History of Humankind  54.23   Five
# ..                                                 ...    ...    ...
# 195                                  Eureka Trivia 6.0  54.59   Four
# 196  Drive: The Surprising Truth About What Motivat...  34.95   Four
# 197            Done Rubbed Out (Reightman & Bailey #1)  37.72   Five
# 198                  Doing It Over (Most Likely To #1)  35.61  Three
# 199  Deliciously Ella Every Day: Quick and Easy Rec...  42.16  Three
#
# [200 rows x 3 columns]
