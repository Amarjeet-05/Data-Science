# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('housing.csv')

# %%
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
df.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %%
df[df['total_bedrooms'].isnull()]
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 290      -122.16     37.77                47.0       1256.0             NaN
# 341      -122.17     37.75                38.0        992.0             NaN
# 538      -122.28     37.78                29.0       5154.0             NaN
# 563      -122.24     37.75                45.0        891.0             NaN
# 696      -122.10     37.69                41.0        746.0             NaN
# ...          ...       ...                 ...          ...             ...
# 20267    -119.19     34.20                18.0       3620.0             NaN
# 20268    -119.18     34.19                19.0       2393.0             NaN
# 20372    -118.88     34.17                15.0       4260.0             NaN
# 20460    -118.75     34.29                17.0       5512.0             NaN
# 20484    -118.72     34.28                17.0       3051.0             NaN
#
# ...

# %%
df['ocean_proximity'].value_counts()
# Out:
# ocean_proximity
# <1H OCEAN     9136
# INLAND        6551
# NEAR OCEAN    2658
# NEAR BAY      2290
# ISLAND           5
# Name: count, dtype: int64

# %%
df.hist(bins=60, figsize=(12,8))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
#as we can see there are 207 missing values in bedrooms and we can easily relate data with the help of the histogram.

# %%
df.plot(kind='scatter', x= 'latitude', y= 'longitude', cmap= 'jet', c= 'median_house_value')
# Out:
# <Axes: xlabel='latitude', ylabel='longitude'>

# %%
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer
# this library is using for handling missing values

# %%
imputer = SimpleImputer(strategy='median')

# %%
x = df.drop('median_house_value', axis=1)
y = df['median_house_value']

# %%
# as in our dataset we have both categoical and numerical data as we are using median strategy it will not work with categorical data so first we need to remove categorical data 
x_num = x.select_dtypes(include=[np.number])
# this removes all categorical data

# %%
imputer.fit(x_num)
# Out:
# SimpleImputer(strategy='median')

# %%
a = imputer.transform(x_num)

# %%
a
# Out:
# array([[-1.2223e+02,  3.7880e+01,  4.1000e+01, ...,  3.2200e+02,
#          1.2600e+02,  8.3252e+00],
#        [-1.2222e+02,  3.7860e+01,  2.1000e+01, ...,  2.4010e+03,
#          1.1380e+03,  8.3014e+00],
#        [-1.2224e+02,  3.7850e+01,  5.2000e+01, ...,  4.9600e+02,
#          1.7700e+02,  7.2574e+00],
#        ...,
#        [-1.2122e+02,  3.9430e+01,  1.7000e+01, ...,  1.0070e+03,
#          4.3300e+02,  1.7000e+00],
#        [-1.2132e+02,  3.9430e+01,  1.8000e+01, ...,  7.4100e+02,
#          3.4900e+02,  1.8672e+00],
#        [-1.2124e+02,  3.9370e+01,  1.6000e+01, ...,  1.3870e+03,
#          5.3000e+02,  2.3886e+00]], shape=(20640, 8))
